# %% [markdown]
# # Capstone Project: Criminal Case Database

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Given the current inefficient processes for beginning legal research, this project seeks to create a proof-of-concept on the creation of an Information Retrieval system in the form of a database of Criminal Law Cases which includes statistical summaries, and legal citations to improve on the speed and efficiency of legal research.
#
# This project will use Natural Language Processing (NLP) to capture the relevant details of each judgment to create a database which can be filtered to provide not only the cases and other relevant cases, but also a statistical summary of the other cases cited in the judgment and other factors such as mitigation or aggravating factors in order to allow faster research which is also more data driven.
#
# The project is intended to be a proof of concept on using data science to increase the efficiency of legal research through the use of statistical summaries and data analysis.

# %% [markdown]
# ### Overall Contents:
# - [Background](#1.-Background) **(In this notebook)**
# - [Webscraping Lawnet](#2.-Webscraping-Lawnet) **(In this notebook)**
# - [Webscraping Singapore Statutes](#3.-Webscraping-Singapore-Statutes) **(In this notebook)**
# - Natural Language Processing
# - Search Function
# - Flask and Google App Engine
# - Conclusion and Recommendation

# %% [markdown]
# ## 1. Background

# %% [markdown]
# Singapore uses the Common Law legal system, where there is an importance of judicial precedents. This means that judges decide cases based on past decisions of the courts. The decisions of higher courts such as the Supreme Court are binding on the lower courts.
# Further to past decisions, in Criminal Law, there is a Penal Code and Criminal Procedure Code which creates a statutory framework for investigation, trials, and sentencing in Criminal Law Cases.
#
# The start of legal research tends to be a slow, manual, and inefficient process. Given the facts of the case at hand, the lawyer first analyzes and determines the relevant area of law to start the research.
# According to a survey done by the ALL-SIS Task Force on Identifying Skills and Knowledge for Legal Practice in 2013, more than half the respondents frequently started their legal research by either looking through statutes or through a case law database, while slightly more than a third would frequently start their research through consulting a subject-specific guide.[1]
# In the current state of the industry, this starting point can take a long time as the statutes and subject-specific guides tend to be wordy, and the case law databases contain many judgments which require further inspection to narrow down according to the case at hand.

# %% [markdown]
# ### 1.1 Datasets
#
# The datasets that I will use will be created by myself through the use of webscraping from legal websites such as LawNet, which contains the judgments, and the Singapore Statutes Online webpage, which contains digital copies of the statutes of Singapore.
#
# The datasets that I will use are as follows:-
#
# * statutes.csv
#
# The datasets that I will create are as follows:-
#
# * subordinatecourt.csv
# * subordinatecourt_compiled.csv
# * statecourt.csv
# * statecourt_compiled.csv
# * statutes_crimes.csv
#
# The information extracted from webscraping Lawnet will be presented in a database in the following format:
#
# |Name|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**court**|*object*|subordinatecourt.csv, subordinatecourt_compiled.csv, statecourt.csv, statecourt_compiled.csv|Court instance|
# |**date**|*datetime*|subordinatecourt.csv, subordinatecourt_compiled.csv, statecourt.csv, statecourt_compiled.csv|Decision date of the judgment|
# |**title**|*object*|subordinatecourt.csv, subordinatecourt_compiled.csv, statecourt.csv, statecourt_compiled.csv|Case name|
# |**link**|*url*|subordinatecourt.csv, subordinatecourt_compiled.csv, statecourt.csv, statecourt_compiled.csv|url of the judgment|
#
#
# The information extracted from webscraping statutes will be presented in a database in the following format:
#
# |Name|Type|Dataset|Description|
# |:---|:---|:---|:---|
# |**section**|*object*|statutes_crimes.csv|The statute section|
# |**title**|*object*|statutes_crimes.csv|The statute title|
# |**link**|*url*|statutes_crimes.csv|url of the statute section|
# |**statute**|*object*|statutes_crimes.csv|Name of the Statute|
# |**section_statute**|*object*|statutes_crimes.csv|Combination of `section` and `statute`|

# %% [markdown]
# ## 2. Webscraping Lawnet

# %% [markdown]
# For the webscraping of judgments from LawNet, I will be using a custom class `Court` which has methods and functions created to do the following:
# 1. Identify the last page of the website as there are multiple pages of entries
# 2. Create a dataframe of all cases which belong to criminal law, including their links
# 3. Identify new cases which are not in my database
# 4. Update the database
# 5. Save each judgment as a .html file (as there is a 3 month free resource limit, this is to enable myself to have more data for the project.)
#
#
# ![lawnet sample](../images/lawnet_sample.png)
#
# A sample of the Lawnet website[2]. The red box shows an example of a criminal case, while the blue box shows the page numbers

# %% [markdown]
# ### 2.1 Court class creation
#
# Going through the custom class, there are two main parts to it:
# 1. Creating a database of criminal cases found on Lawnet
# 2. Archiving the html file for each new criminal case in the database
#
# The first step is to create the class Court, and initialize it.
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
# # Create the Court class
# class Court:
#
#     def __init__(self, name):
#         """
#         Create a court. Only accepts "subordinate" and "supreme".
#         """
#         # Set the name of the instance
#         self.name = name
#
#         # Raise an error if the user tries to create an instance of a court that does not exist
#         if self.name != 'subordinate' and self.name != 'supreme':
#             raise CourtNameError("There is only the Subordinate (State) or Supreme Court!")
# ```
# </details>
#
# An error is raised if any instance other than 'subordinate' or 'supreme' is created as there are only two court categories on Lawnet.

# %% [markdown]
# ### 2.2 Creating a database of criminal cases found on Lawnet
#
# #### 2.2.1 Lawnet information
# Next, the class needs a few key pieces of information before it can iterate through and scrape the Lawnet website for new judgments:
# * The target url for requests
# * The number of pages to iterate through
#
# Hence, I created two private methods which capture these pieces of information.
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
#     def __set_soup(self):
#         """
#         Sets the target Court's Lawnet page using `name`.
#         """
#         # Set the url for API requests
#         self.url = "https://www.lawnet.sg/lawnet/web/lawnet/free-resources?p_p_id=freeresources_WAR_lawnet3baseportlet&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&p_p_col_id=column-1&p_p_col_pos=2&p_p_col_count=3&_freeresources_WAR_lawnet3baseportlet_action="+self.name
#
#         # Set the variables for BeautifulSoup parsing
#         self.response = requests.get(self.url)
#         self.html = self.response.text
#         self.court = BeautifulSoup(self.html, 'lxml')
#
#     def __get_num_pages(self):
#         """
#         Fetches number of pages from the website as an int
#         """
#         # Check for the last page from the html code
#         self.page = str(self.court.find_all('li', {'class': 'lastPageActive'}))
#         self.page = ''.join(filter(str.isdigit, self.page))
#
#         # Replace the first "3" as it comes from the url
#         self.last_page = int(self.page.replace("3","",1))
# ```
# </details>
#
# The first method lets the class know what the url for the particular court instance is, and the second lets the class know what the last page of entries is.

# %% [markdown]
# #### 2.2.2 Pulling urls
#
# With the key information set, now I created a code to crawl through the Lawnet page to pull and create a dataframe of new judgments and their respective links.
#
# This private method `__fetch_urls` first creates a variable for the base domain for all lawnet judgments, then iterates through the pages until it completes the last page which was previously identified, capturing the court category as `court`, decision date as `date`, case name as `title`, and judgment link as `link` for each entry in a dictionary.
#
# Each dictionary is then appended to a list which is finally converted to a pandas dataframe which is sorted by date, with the newest entries at the bottom.
# <details>
#     <summary> <b> Click here for code (warning: long code) </b></summary>
#
# ```python
#     def __fetch_urls(self):
#         """
#         Uses `name` to scrape lawnet for the cases and urls and store it in a dataframe `court_df`.
#         """
#         # Create an empty list for results
#         self.results_list = []
#
#         # Set the base domain for the urls
#         self.domain = "https://www.lawnet.sg/lawnet/web/lawnet/free-resources?p_p_id=freeresources_WAR_lawnet3baseportlet&p_p_lifecycle=1&p_p_state=normal&p_p_mode=view&p_p_col_id=column-1&p_p_col_pos=2&p_p_col_count=3&_freeresources_WAR_lawnet3baseportlet_action=openContentPage&_freeresources_WAR_lawnet3baseportlet_docId="
#
#         # Create counter for current page
#         self.current_page = 1
#
#         # Loop while it is not the last page
#         while self.current_page <= self.last_page:
#
#             # Set the full url for the current page
#             url1 = self.url+"&_freeresources_WAR_lawnet3baseportlet_page="+str(self.current_page)
#
#             # Establishing the connection to the web page:
#             response1 = requests.get(url1)
#
#             # Pull the HTML string out of requests and convert it to a Python string.
#             html1 = response1.text
#             court1 = BeautifulSoup(html1, 'lxml')
#
#             # Get the relevant elements (date, name, link)
#             search_results = court1.find_all('ul', {'class': 'searchResultsHolder'})
#
#             # Iterate throught the search results to find the list elements
#             for li in search_results:
#                 li_list = li.find_all('li')
#                 for element in li_list:
#                    # start a dictionary to store this item's data
#                     result = {}
#
#                     # Set the court
#                     result['court'] = self.name
#
#                     # get the date
#                     result['date'] = element.find('p', {'class': 'resultsDate'}).text
#
#                     # get the title and full link/url
#                     a_href = element.find('a')
#                     if a_href:
#                         result['title'] = a_href.text.strip()   # element text
#                         link = str(a_href['href']) # href link
#
#                         # Remove unnecessary parts of the link
#                         link = link.replace("javascript:viewContent","")
#                         link = link.strip("')(")
#
#                         # Add the result including the domain
#                         result['link'] = self.domain+link
#
#                         # only store "full" rows of data
#                         if len(result) == 4:
#                             self.results_list.append(result)
#
#                     # Clear cell output
#                     clear_output(wait=True)
#
#                     # Print current progress
#                     print(f'Current progress: page {self.current_page}/{self.last_page}.')
#
#             # Raise page counter for the loop to pull results from the next page
#             self.current_page += 1
#
#         # Create a dataframe with all the links, sorted by date
#         self.court_df = pd.DataFrame(self.results_list)
#         self.court_df = self.court_df.sort_values(by='date')
#         self.court_df = self.court_df.reset_index(drop=True)
#
#         # Print current progress
#         print(f'Current progress: DataFrame created.')
# ```
# </details>

# %% [markdown]
# #### 2.2.2.3 Filtering to only criminal cases
#
# With this dataframe created, the results are filtered to those where "Public Prosecutor" appears in the `title` as all criminal cases will have this pattern in it.
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
#
#     def __only_crim(self):
#         """
#         Narrows results to only Criminal cases
#         """
#         # Filters to cases where "Public Prosecutor" is mentioned - these are criminal cases
#         self.court_df = self.court_df[self.court_df['title'].str.contains("Public Prosecutor")]
#         self.court_df = self.court_df.reset_index(drop=True)
#
#         # Print current progress
#         print(f'Current progress: Narrowed to only Criminal cases.')
#
# ```
# </details>

# %% [markdown]
# #### 2.2.2.4 Comparison against existing database
#
# The dataframe is then compared against the existing database to identify new entries and merge them into the existing database.
#
# This step has two purposes:
# 1. I do not want duplicate entries in the database
# 2. For the archival step, we only want to archive new judgments which have not been previously archived
#
# Once the comparison is done, the database is sorted by date, and both the new entries and updated database are saved in separate .csv files.
#
# <details>
#     <summary> <b> Click here for comparison code </b></summary>
#
# ```python
#     def __compare_csv(self):
#         """
#         Loads the complete csv database and compares data with the dataframe to identify new entries.
#         Returns new entries as `court_df` and all entries as `court_full`.
#         """
#         # Convert dates to datetime
#         self.court_df['date'] = pd.to_datetime(self.court_df['date'], dayfirst=True)
#
#         # Load the full dataset .csv and convert dates to datetime
#         self.court_full = pd.read_csv(f'../data/{self.name}court_compiled.csv')
#         self.court_full['date'] = pd.to_datetime(self.court_full['date'], format='%Y-%m-%d')
#
#         # Filter to entries which are not in the full dataset
#         self.court_df = self.court_df[~self.court_df['link'].isin(self.court_full['link'])]
#
#         # Merge new entries to the full dataset, sorted by date
#         self.court_full = self.court_full.merge(self.court_df, how='outer')
#         self.court_full = self.court_full.sort_values(by='date')
#         self.court_full = self.court_full.reset_index(drop=True)
#
#
#         # Print current progress
#         print(f'Current progress: {len(self.court_df.date)} New entries identified and saved.')
#
# ```
# </details>
#
# <details>
#     <summary> <b> Click here for exporting code </b></summary>
#
# ```python
#     def __export_csv(self):
#         """
#         Exports dataframes to the respective .csv files
#         """
#         # Save the new entries in a .csv
#         self.court_df.to_csv(path_or_buf=f'../data/{self.name}court.csv', index=False)
#
#         # Save the new full dataset in a .csv
#         self.court_full.to_csv(path_or_buf=f'../data/{self.name}court_compiled.csv', index=False)
#
#
# ```
# </details>

# %% [markdown]
# #### 2.2.2.5  Public method to pull the urls
#
# The above methods were all private methods. To actually pull the urls from Lawnet, I created a method containing a pipeline that joins together the above steps.
#
# This method also creates or updates a log of when I last pulled urls from Lawnet.
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
#     def pull_urls(self):
#         """
#         Call command to pull urls and export to csv database
#         """
#         # Call the functions required to pull the urls from Lawnet
#         self.__set_soup()
#         self.__get_num_pages()
#         self.__fetch_urls()
#         self.__only_crim()
#         self.__compare_csv()
#         self.__export_csv()
#
#         # Write a log of the last pull date
#         self.file = open('../logs/pull_log.txt', 'a', encoding='utf_8')
#         self.file.write(f'list last updated on: {datetime.today()}; \n')
#
#         # Print current progress
#         print(f'Current progress: Completed url pull and export.')
#
# ```
# </details>
#
# Hence, with the above methods, I was able to scrape and create a database of judgments from Lawnet which can be updated with no duplicates by running it again.

# %% [markdown]
# ### 2.3 Archiving the judgments from Lawnet
#
# #### 2.3.1 Loading the database
#
# For the archival of judgments from Lawnet, I first created a method to load the database .csv files as pandas dataframes.
# I did this as I wanted to prevent any clashes between any dataframes which may be stored in memory and the actual database which has been saved.
#
# The date column of the dataframe is converted to datetime format to prevent any potential errors in sorting.
#
# At the same time, this method also creates a dictionary of the `links` column in the database which is compared to the `links` of the new entries to identify and assign them a `key1`, which is their index in the database, which will be used for the export file name.
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
#     def load_csv(self):
#         """
#         Loads .csvs using `name` as lists of dictionaries.
#         """
#         # Load the .csv files as pandas dataframes
#         self.court_link_list = [pd.read_csv(f'../data/{self.name}court.csv').link.to_dict()]
#         self.court_link_dict = pd.read_csv(f'../data/{self.name}court_compiled.csv').link.to_dict()
#         self.court_full = pd.read_csv(f'../data/{self.name}court_compiled.csv')
#         self.court_full['date'] = pd.to_datetime(self.court_full['date'], format='%Y-%m-%d')
#
# ```
# </details>
#
# This is not a private method as I want to be able to load the database at any time without having to archive the files.

# %% [markdown]
# #### 2.3.2 Saving the judgments as .html
#
# For the actual archival, I first set a base file name for each file which consists of the `court` name of the instance and the string `court`.
#
# Next, the method iterates through each link from the new entries dataset to send a request to the url, returning a BeautifulSoup parsed response.
#
# This response is then saved as a .html file in the judgments folder, with the file name according to their assigned key1.
#
# To avoid overloading the servers, a random sleep timer is set for between 1 and 4 seconds between each archival.
#
# If there are any errors, the archival for the judgment is skipped and an error log is created.
#
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
#     def __save_html(self):
#         """
#         Iterates through the lists of dictionaries to save judgments from Lawnet as a .html file.
#         """
#         # Create a counter for the progress bar
#         self.count = 1
#
#         # Sets the file name for the judgment
#         self.file_name = self.name+'court'
#
#         # Iterate through the list of new link entries
#         for item in self.court_link_list:
#             for key, value in item.items():
#                 # Sets the request for the link
#                 url = value
#                 response = requests.get(url)
#
#                 # Pull the HTML string out of requests and convert it to a Python string.
#                 html = response.text
#                 soup = BeautifulSoup(html, 'lxml')
#
#                 # Match value to key in full list for file name
#                 key1 = list(self.court_link_dict.keys())[list(self.court_link_dict.values()).index(value)]
#                 try:
#                     # Try to save as html file
#                     file = open(f'../judgments/{self.name}_court/{self.file_name}_{key1}.html', 'x', encoding='utf_8')
#                     file.write(str(soup))
#                     file.close
#                     sleep(randint(1,4))
#
#                     # Clear cell output
#                     clear_output(wait=True)
#
#                     # Print current progress
#                     print(f'Current progress: {self.count}/{len(self.court_link_list[0])}.')
#                     self.count += 1
#
#                 except:
#                     # Skip if error, print an error log with index
#                     file = open('../logs/error_log.txt', 'a', encoding='utf_8')
#                     file.write(f'{self.file_name}_list error: {key1}.html : {datetime.today()}; \n')
#
#                     # Clear cell output
#                     clear_output(wait=True)
#
#                     # Print current progress
#                     print(f'Current progress: {self.count}/{len(self.court_link_list[0])}.')
#                     self.count += 1
#
# ```
# </details>

# %% [markdown]
# #### 2.3.3 Public method to archive the judgments
#
# Similar to the pulling of cases from Lawnet, I created a pipeline method which calls the functions in order to archive the new entries from Lawnet.
#
# <details>
#     <summary> <b> Click here for code </b></summary>
#
# ```python
#     def archive(self):
#         """
#         Call command to archive the urls as .html files.
#         """
#         # Call the functions required to archive the new html files from Lawnet
#         self.load_csv()
#         self.__save_html()
#
#         # Update the log file for the last archival date
#         self.file = open('../logs/archival_log.txt', 'a', encoding='utf_8')
#         self.file.write(f'last archived on: {datetime.today()}; \n')
#
#         # Print current progress
#         print(f'Current progress: {len(self.court_link_list[0])} HTMLs archived.')
#
# ```
# </details>
#
# With the methods for pulling the urls and archiving the files split, I am able to perform each task separately in case I do not want to perform it all at once, or in case any errors occur.

# %% [markdown]
# ### 2.4 Testing the custom class
#
# #### 2.4.1 Libraries Import
#
# I will import the custom class `Court` and pandas to explore the results of the code.

# %%
# Import libaries
import pandas as pd
from criminalcasedatabase import Court

# %% [markdown]
# ### 2.5 Create an instance for the Supreme Court and pull the urls

# %%
supreme_court = Court('supreme')
supreme_court.pull_urls()
# Out:
# Current progress: page 6/6.
# Current progress: DataFrame created.
# Current progress: Narrowed to only Criminal cases.
# Current progress: 1 New entries identified and saved.
# Current progress: Completed url pull and export.

# %% [markdown]
# Exploring the new entries dataframe:

# %%
supreme_court.court_df.head()
# Out:
#      court       date                                              title  \
# 1  supreme 2021-06-03  Mohammad Farid bin Batra v Public Prosecutor -...
#
#                                                 link
# 1  https://www.lawnet.sg/lawnet/web/lawnet/free-r...

# %% [markdown]
# Exploring the full database:

# %%
supreme_court.court_full.tail()
# Out:
#       court       date                                              title  \
# 41  supreme 2021-05-14  Syed Suhail bin Syed Zin v Public Prosecutor -...
# 42  supreme 2021-05-18  Tan Kok Meng v Public Prosecutor - [2021] SGCA 55
# 43  supreme 2021-05-19  Public Prosecutor v Mangalagiri Dhruva Kumar -...
# 44  supreme 2021-06-02  Sulaiman bin Mohd Hassan v Public Prosecutor -...
# 45  supreme 2021-06-03  Mohammad Farid bin Batra v Public Prosecutor -...
#
#                                                  link
# 41  https://www.lawnet.sg/lawnet/web/lawnet/free-r...
# 42  https://www.lawnet.sg/lawnet/web/lawnet/free-r...
# 43  https://www.lawnet.sg/lawnet/web/lawnet/free-r...
# 44  https://www.lawnet.sg/lawnet/web/lawnet/free-r...
# 45  https://www.lawnet.sg/lawnet/web/lawnet/free-r...

# %% [markdown]
# The newest entries are stored at the bottom to prevent the overwriting of keys during judgment archival.
#
# If the newest entries are at the top, the index of all the rows will keep changing.

# %% [markdown]
# ### 2.6 Archive the htmls

# %%
supreme_court.archive()
# Out:
# Current progress: 1/1.
# Current progress: 1 HTMLs archived.

# %% [markdown]
# The code ran fine and the html has now been archived in its respective project subfolder.
#
# ![archived](../images/archived.png)

# %% [markdown]
# ### 2.7 Create an instance for the Subordinate Courts and pull the urls

# %% [markdown]
# Repeating the steps for the other court:

# %%
state_court = Court('subordinate')
state_court.pull_urls()
# Out:
# Current progress: page 4/4.
# Current progress: DataFrame created.
# Current progress: Narrowed to only Criminal cases.
# Current progress: 0 New entries identified and saved.
# Current progress: Completed url pull and export.

# %% [markdown]
# ### 2.8 Archive the htmls

# %%
state_court.archive()
# Out:
# Current progress: 0 HTMLs archived.

# %% [markdown]
# The code has worked without any errors, and I now have the judgments archived as .html files for processing in the next notebook.

# %% [markdown]
# ## 3. Webscraping Singapore Statutes

# %% [markdown]
# Criminal offences in Singapore are not listed in a central database or statute, but found within many different statutes. Given the vast number of statutes where criminal offences can be found, I will limit the scope to the some of the statutes in Singapore based on criminal offences as listed in [Gloria James-Civetta & Co's article on Singapore Crimes and Punishment](https://www.singaporecriminallawyer.com/crimes-punishment/)[3].
#
# Due to each statute being different and full of nuances, I will manually create databases of crimes from each of the statutes which are available from [Singapore Statutes Online](sso.agc.gov.sg).
#
# This database of possible criminal offences will be used for the information retrieval as one of the items for the NLP identification is the criminal offence in each judgment.

# %% [markdown]
# ### Additional Libraries Import

# %% [markdown]
# For the webscraping of Singapore Statutes, I will use `requests`, `BeautifulSoup`, and `re`.

# %%
# Imports

import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ### Statutes

# %% [markdown]
# The following are the Singapore Statutes which I will be using and their links, manually compiled into a .csv file:

# %%
statutes = pd.read_csv('../data/statutes.csv')

# %%
statutes
# Out:
#                                               statute  \
# 0                                 Misuse of Drugs Act
# 1                                        Sedition Act
# 2                                       Vandalism Act
# 3                      Children and Young Persons Act
# 4                                     Immigration Act
# 5                                      Income Tax Act
# 6                                       Companies Act
# 7                        Prevention of Corruption Act
# 8                                         Customs Act
# 9                                    Road Traffic Act
# 10                    Environmental Public Health Act
# 11                                Computer Misuse Act
# 12                                         Penal Code
# 13                            Employment Agencies Act
# 14                 Employment of Foreign Manpower Act
# 15                    Workplace Safety and Health Act
# 16                       Work Injury Compensation Act
# 17  Corruption, Drug Trafficking and Other Serious...
#
#                                         link
# 0         https://sso.agc.gov.sg/Act/MDA1973
# 1          https://sso.agc.gov.sg/Act/SA1948
# 2          https://sso.agc.gov.sg/Act/VA1966
# 3        https://sso.agc.gov.sg/Act/CYPA1993
# 4          https://sso.agc.gov.sg/Act/IA1959
# 5         https://sso.agc.gov.sg/Act/ITA1947
# 6         https://sso.agc.gov.sg/Act/CoA1967
# 7         https://sso.agc.gov.sg/Act/PCA1960
# 8          https://sso.agc.gov.sg/Act/CA1960
# 9         https://sso.agc.gov.sg/Act/RTA1961
# 10       https://sso.agc.gov.sg/Act/EPHA1987
# 11        https://sso.agc.gov.sg/Act/CMA1993
# 12         https://sso.agc.gov.sg/Act/PC1871
# 13        https://sso.agc.gov.sg/Act/EAA1958
# 14       https://sso.agc.gov.sg/Act/EFMA1990
# 15       https://sso.agc.gov.sg/Act/WSHA2006
# 16       https://sso.agc.gov.sg/Act/WICA2019
# 17  https://sso.agc.gov.sg/Act/CDTOSCCBA1992

# %% [markdown]
# # 3.1 Scraping code creation
#
# Starting with the Penal Code, I will identify the relevant data from the html in order to create a database containing the section, crime name, and link in order to create a database.
# This will then be used to create a function that can be run on the other statutes.

# %% [markdown]
# ## 3.1.1 Penal Code
# ### Fetch the Penal Code content by URL.

# %%
# Target Penal Code Statute page:
url = statutes[statutes['statute'] == 'Penal Code'].link.values[0]

headers = requests.utils.default_headers()
headers.update(
    {
        'User-Agent': 'Mozilla/5.0',
    }
)

# Establishing the connection to the web page:
response = requests.get(url, headers=headers)

# You can use status codes to understand how the target server responds to your request.
# Ex., 200 = OK, 400 = Bad Request, 403 = Forbidden, 404 = Not Found.
print(response.status_code)

# Pull the HTML string out of requests and convert it to a Python string.
html = response.text
# Out:
# 200

# %% [markdown]
# ### Parse the HTML document with Beautiful Soup.
#
# This step allows me to access the elements of the webpage.

# %%
penal_code = BeautifulSoup(html, 'lxml')

# %%
# This code collects the sections and links from the statute and puts it into a database 

# List to store results
results_list = []

# Get the relevant elements (name, link) from all 'ul' with class 'nav' (exact match)
search_results = penal_code.find_all(lambda tag: tag.name == 'ul' and 
                                   tag.get('class') == ['nav'])
# Iterate through the unordered lists
for ul in search_results:
    # Find the lists within
    li_list = ul.find_all('li')
    # Iterate through the lists to get each section
    for element in li_list:
        # start a dictionary to store this item's data
        result = {}
        # get the title and full link/url
        a_href = element.find('a')
        # Skip section if it is repealed
        if 'Repealed' in a_href.text.strip():
            continue
        # Split text to section and title
        else:
            text = a_href.text.strip().split(' ', 1)
            result['section'] = text[0]
            result['title'] = text[1]   # element text
        # Add the link
        result['link'] = url+str(a_href['href']) # href link
        result['statute'] = 'Penal Code'
        results_list.append(result)

penal_code_df = pd.DataFrame(results_list)

# %% [markdown]
# ### Narrow to sections containing offences
#
# Currently, this has to be done manually based on my domain knowledge. Within the scope of the project, I will not be creating an NLP algorithm to automate this due to a lack of time, but this should be improved on in the future through machine learning.

# %%
# Limit the sections to those containing offences (crimes)
penal_code_df = penal_code_df.iloc[104:,:]

# %%
penal_code_df
# Out:
#     section                                              title  \
# 104     107                   Abetment of the doing of a thing
# 105     108                                            Abettor
# 106    108A  Abetment in Singapore of an offence outside Si...
# 107    108B  Abetment outside Singapore of an offence in Si...
# 108     109  Punishment of abetment if the act abetted is c...
# ..      ...                                                ...
# 522     505            Statements conducing to public mischief
# 523     506               Punishment for criminal intimidation
# 524     507  Criminal intimidation by an anonymous communic...
# 525     511                          Attempt to commit offence
# 526     512       Punishment for attempting to commit offences
#
#                                           link     statute
# 104   https://sso.agc.gov.sg/Act/PC1871#pr107-  Penal Code
# 105   https://sso.agc.gov.sg/Act/PC1871#pr108-  Penal Code
# 106  https://sso.agc.gov.sg/Act/PC1871#pr108A-  Penal Code
# 107  https://sso.agc.gov.sg/Act/PC1871#pr108B-  Penal Code
# 108   https://sso.agc.gov.sg/Act/PC1871#pr109-  Penal Code
# ..                                         ...         ...
# 522   https://sso.agc.gov.sg/Act/PC1871#pr505-  Penal Code
# 523   https://sso.agc.gov.sg/Act/PC1871#pr506-  Penal Code
# 524   https://sso.agc.gov.sg/Act/PC1871#pr507-  Penal Code
# 525   https://sso.agc.gov.sg/Act/PC1871#pr511-  Penal Code
# 526   https://sso.agc.gov.sg/Act/PC1871#pr512-  Penal Code
#
# [423 rows x 4 columns]

# %% [markdown]
# ### 3.1.2. Putting the scraping into a function

# %% [markdown]
# Having tested the code on the Penal Code, I will proceed to place it into a function to be used for the other Statutes.
#
# This code will create a dataframe containing the `section`, `title` of each section, their internal `link`, and the name of the `statute`.

# %%
def get_statute_sections(statute):
    """
    Input: Statute as a string
    Output: Database of sections, titles, and urls for the statute
    """
    print(statute)
    url = statutes[statutes['statute'] == statute].link.values[0]
    print(url)
    headers = requests.utils.default_headers()
    headers.update(
        {
            'User-Agent': 'Mozilla/5.0',
        }
    )
    # Establishing the connection to the web page:
    response = requests.get(url, headers=headers)

    # You can use status codes to understand how the target server responds to your request.
    # Ex., 200 = OK, 400 = Bad Request, 403 = Forbidden, 404 = Not Found.
    print(f'response: {response.status_code}')

    # Pull the HTML string out of requests and convert it to a Python string.
    html = response.text
    statute_html = BeautifulSoup(html, 'lxml')
    # This code collects the sections and links from the statute and puts it into a database 
    # List to store results
    results_list = []

    # Get the relevant elements (name, link) from all 'ul' with class 'nav' (exact match)
    search_results = statute_html.find_all(lambda tag: tag.name == 'ul' and 
                                       tag.get('class') == ['nav'])
    # Iterate through the unordered lists
    for ul in search_results:
        # Find the lists within
        li_list = ul.find_all('li')
        # Iterate through the lists to get each section
        for element in li_list:
            # start a dictionary to store this item's data
            result = {}
            # get the title and full link/url
            a_href = element.find('a')
            # Skip section if it is repealed
            if 'Repealed' in a_href.text.strip():
                continue
            # Split text to section and title
            else:
                text = a_href.text.strip().split(' ', 1)
                result['section'] = text[0]
                result['title'] = text[1]   # element text
            # Add the link
            result['link'] = url+str(a_href['href']) # href link
            result['statute'] = statute
            # Append the section to the results_list
            results_list.append(result)
        
    # Create the dataframe from the results_list
    statute_df = pd.DataFrame(results_list)
    print('no errors, task completed!')
    return statute_df

# %% [markdown]
# ### 3.1.3 Misuse of Drugs Act
#
# Now that I have created a function to scrape the sections and links for the statutes, I will use it for the other Statutes within the project's scope, and use my domain knowledge to narrow each statute to the possible criminal offences.
#
# The dataframes for each statute will be created by only appending the relevant rows containing the offences based on my manual determination.

# %%
statute_df = get_statute_sections('Misuse of Drugs Act')
# Out:
# Misuse of Drugs Act
# https://sso.agc.gov.sg/Act/MDA1973
# response: 200
# no errors, task completed!

# %%
statute_df
# Out:
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2        3  Appointment of Director and other officers of ...
# 3        4                                Advisory committees
# 4        5                    Trafficking in controlled drugs
# ..     ...                                                ...
# 75      56                                     Use of weapons
# 76      57  Employment of auxiliary police officers as esc...
# 77      58                                        Regulations
# 78     58A  Specifying drugs as temporarily listed drugs i...
# 79      59  Power of Minister to amend First, Third and Fo...
#
#                                          link              statute
# 0     https://sso.agc.gov.sg/Act/MDA1973#pr1-  Misuse of Drugs Act
# 1     https://sso.agc.gov.sg/Act/MDA1973#pr2-  Misuse of Drugs Act
# 2     https://sso.agc.gov.sg/Act/MDA1973#pr3-  Misuse of Drugs Act
# 3     https://sso.agc.gov.sg/Act/MDA1973#pr4-  Misuse of Drugs Act
# 4     https://sso.agc.gov.sg/Act/MDA1973#pr5-  Misuse of Drugs Act
# ..                                        ...                  ...
# 75   https://sso.agc.gov.sg/Act/MDA1973#pr56-  Misuse of Drugs Act
# 76   https://sso.agc.gov.sg/Act/MDA1973#pr57-  Misuse of Drugs Act
# 77   https://sso.agc.gov.sg/Act/MDA1973#pr58-  Misuse of Drugs Act
# 78  https://sso.agc.gov.sg/Act/MDA1973#pr58A-  Misuse of Drugs Act
# 79   https://sso.agc.gov.sg/Act/MDA1973#pr59-  Misuse of Drugs Act
#
# [80 rows x 4 columns]

# %%
misuse_drugs_act_df = statute_df.iloc[4:22,:]

# %%
misuse_drugs_act_df = misuse_drugs_act_df.append(statute_df.iloc[44:47,:])

# %%
misuse_drugs_act_df.reset_index(drop = True)
# Out:
#    section                                              title  \
# 0        5                    Trafficking in controlled drugs
# 1        6                    Manufacture of controlled drugs
# 2        7              Import and export of controlled drugs
# 3        8     Possession and consumption of controlled drugs
# 4       8A  Consumption of drug outside Singapore by citiz...
# 5        9                Possession of pipes, utensils, etc.
# 6       10     Cultivation of cannabis, opium and coca plants
# 7      10A  Manufacture, supply, possession, import or exp...
# 8      10B  Regulations on controlled equipment, material ...
# 9       11          Responsibilities of owners, tenants, etc.
# 10     11A  Arranging or planning gatherings where control...
# 11     11B  Exposing child to drugs, etc., and permitting ...
# 12     11C      Introducing drug trafficker to another person
# 13     11D  Instructing person to cultivate cannabis, etc....
# 14     11E  Causing or procuring young person or vulnerabl...
# 15      12      Abetments and attempts punishable as offences
# 16      13  Abetting or procuring commission of offences w...
# 17      14                         Offences by body corporate
# 18      33                            Punishment for offences
# 19     33A  Punishment for repeat consumption of specified...
# 20     33B  Discretion of court not to impose sentence of ...
#
#                                          link              statute
# 0     https://sso.agc.gov.sg/Act/MDA1973#pr5-  Misuse of Drugs Act
# 1     https://sso.agc.gov.sg/Act/MDA1973#pr6-  Misuse of Drugs Act
# 2     https://sso.agc.gov.sg/Act/MDA1973#pr7-  Misuse of Drugs Act
# 3     https://sso.agc.gov.sg/Act/MDA1973#pr8-  Misuse of Drugs Act
# 4    https://sso.agc.gov.sg/Act/MDA1973#pr8A-  Misuse of Drugs Act
# 5     https://sso.agc.gov.sg/Act/MDA1973#pr9-  Misuse of Drugs Act
# 6    https://sso.agc.gov.sg/Act/MDA1973#pr10-  Misuse of Drugs Act
# 7   https://sso.agc.gov.sg/Act/MDA1973#pr10A-  Misuse of Drugs Act
# 8   https://sso.agc.gov.sg/Act/MDA1973#pr10B-  Misuse of Drugs Act
# 9    https://sso.agc.gov.sg/Act/MDA1973#pr11-  Misuse of Drugs Act
# 10  https://sso.agc.gov.sg/Act/MDA1973#pr11A-  Misuse of Drugs Act
# 11  https://sso.agc.gov.sg/Act/MDA1973#pr11B-  Misuse of Drugs Act
# 12  https://sso.agc.gov.sg/Act/MDA1973#pr11C-  Misuse of Drugs Act
# 13  https://sso.agc.gov.sg/Act/MDA1973#pr11D-  Misuse of Drugs Act
# 14  https://sso.agc.gov.sg/Act/MDA1973#pr11E-  Misuse of Drugs Act
# 15   https://sso.agc.gov.sg/Act/MDA1973#pr12-  Misuse of Drugs Act
# 16   https://sso.agc.gov.sg/Act/MDA1973#pr13-  Misuse of Drugs Act
# 17   https://sso.agc.gov.sg/Act/MDA1973#pr14-  Misuse of Drugs Act
# 18   https://sso.agc.gov.sg/Act/MDA1973#pr33-  Misuse of Drugs Act
# 19  https://sso.agc.gov.sg/Act/MDA1973#pr33A-  Misuse of Drugs Act
# 20  https://sso.agc.gov.sg/Act/MDA1973#pr33B-  Misuse of Drugs Act

# %% [markdown]
# ### 3.1.4 Sedition Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[1])
# Out:
# Sedition Act
# https://sso.agc.gov.sg/Act/SA1948
# response: 200
# no errors, task completed!

# %%
sedition_act_df = statute_df.iloc[3:4,:].reset_index(drop=True)
sedition_act_df
# Out:
#   section     title                                    link       statute
# 0       4  Offences  https://sso.agc.gov.sg/Act/SA1948#pr4-  Sedition Act

# %% [markdown]
# ### 3.1.5 Vandalism Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[2])
# Out:
# Vandalism Act
# https://sso.agc.gov.sg/Act/VA1966
# response: 200
# no errors, task completed!

# %%
statute_df
# Out:
#   section                                              title  \
# 0       1                                        Short title
# 1       2                                     Interpretation
# 2       3                      Penalty for acts of vandalism
# 3       4  Written authority or written consent to be pro...
# 4       5  Power to seize article or thing in respect of ...
# 5       6         Offences to be arrestable and non-bailable
# 6       7                                        Presumption
# 7       8  Revocation of secondhand goods dealer’s licenc...
#
#                                      link        statute
# 0  https://sso.agc.gov.sg/Act/VA1966#pr1-  Vandalism Act
# 1  https://sso.agc.gov.sg/Act/VA1966#pr2-  Vandalism Act
# 2  https://sso.agc.gov.sg/Act/VA1966#pr3-  Vandalism Act
# 3  https://sso.agc.gov.sg/Act/VA1966#pr4-  Vandalism Act
# 4  https://sso.agc.gov.sg/Act/VA1966#pr5-  Vandalism Act
# 5  https://sso.agc.gov.sg/Act/VA1966#pr6-  Vandalism Act
# 6  https://sso.agc.gov.sg/Act/VA1966#pr7-  Vandalism Act
# 7  https://sso.agc.gov.sg/Act/VA1966#pr8-  Vandalism Act

# %%
vandalism_act_df = statute_df.iloc[1:4,:].reset_index(drop=True)
vandalism_act_df
# Out:
#   section                                              title  \
# 0       2                                     Interpretation
# 1       3                      Penalty for acts of vandalism
# 2       4  Written authority or written consent to be pro...
#
#                                      link        statute
# 0  https://sso.agc.gov.sg/Act/VA1966#pr2-  Vandalism Act
# 1  https://sso.agc.gov.sg/Act/VA1966#pr3-  Vandalism Act
# 2  https://sso.agc.gov.sg/Act/VA1966#pr4-  Vandalism Act

# %% [markdown]
# ### 3.1.6 Children and Young Persons Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[3])
# Out:
# Children and Young Persons Act
# https://sso.agc.gov.sg/Act/CYPA1993
# response: 200
# no errors, task completed!

# %%
statute_df.head(50)
# Out:
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2        3              Administration and enforcement of Act
# 3       3A                                         Principles
# 4        4  When child or young person in need of care or ...
# 5        5             Ill-treatment of child or young person
# 6        6  Contribution to delinquency of child or young ...
# 7        7       Sexual exploitation of child or young person
# 8        8        Power to obtain and communicate information
# 9       8A  Power to order child or young person to be pro...
# 10       9  Power to remove child or young person to place...
# 11      9A  Assessment, examination and treatment of child...
# 12      10  Warrant to search for or remove child or young...
# 13      11  Restrictions on children and young persons tak...
# 14     11A                          Voluntary care agreements
# 15      12  Unlawful transfer of possession, custody or co...
# 79    https://sso.agc.gov.sg/Act/IA1959#pr56-  Immigration Act
# 80    https://sso.agc.gov.sg/Act/IA1959#pr57-  Immigration Act
# 81   https://sso.agc.gov.sg/Act/IA1959#pr57A-  Immigration Act
# 82   https://sso.agc.gov.sg/Act/IA1959#pr57B-  Immigration Act
# 83   https://sso.agc.gov.sg/Act/IA1959#pr57C-  Immigration Act
# 84   https://sso.agc.gov.sg/Act/IA1959#pr57D-  Immigration Act
# 85    https://sso.agc.gov.sg/Act/IA1959#pr58-  Immigration Act
# 86    https://sso.agc.gov.sg/Act/IA1959#pr59-  Immigration Act
# 87    https://sso.agc.gov.sg/Act/IA1959#pr60-  Immigration Act
# 88    https://sso.agc.gov.sg/Act/IA1959#pr61-  Immigration Act
# 89   https://sso.agc.gov.sg/Act/IA1959#pr61A-  Immigration Act
# 90    https://sso.agc.gov.sg/Act/IA1959#pr62-  Immigration Act

# %%
immigration_act_df = statute_df.iloc[4:11,:]
immigration_act_df = immigration_act_df.append(statute_df.iloc[[17,45,50,53,57,62],:])
immigration_act_df = immigration_act_df.append(statute_df.iloc[21:44,:])
immigration_act_df = immigration_act_df.append(statute_df.iloc[64:66,:])
immigration_act_df = immigration_act_df.append(statute_df.iloc[80:86,:])
immigration_act_df = immigration_act_df.reset_index(drop=True)
immigration_act_df
# Out:
#    section                                              title  \
# 0        5            Entry into and departure from Singapore
# 1       5A  Person entering or leaving Singapore to produc...
# 2       5B                     Facilities at authorised areas
# 3        6  Control of entry into and departure from Singa...
# 4       6A                     Non-citizens born in Singapore
# 5        7                                     Right of entry
# 6        8                              Prohibited immigrants
# 7      11A        Persons ceasing to be citizens of Singapore
# 8      31A  Power of Controller to remove prohibited immig...
# 9       36                      Unlawful return after removal
# 10     36C  Accessing or disclosing identifying informatio...
# 11      39                    Power to summon witnesses, etc.
# 12      42  Signing on or bringing as member of the crew a...
# 13      15            Unlawful entry or presence in Singapore
# 14      16                                 Immigration signal
# 15      17  Vessel to stop, proceed to immigration or depa...
# 16      18   Aircraft arriving in or departing from Singapore
# 17     18A             Train arriving in or leaving Singapore
# 18     18B          Vehicles arriving in or leaving Singapore
# 19      19  Persons not to board or leave vessel until exa...
# 20      20  Prohibition on disembarking from or boarding s...
# 21      21  Prohibition of removal of articles before exam...
# 22      22  Provision of passenger and crew information by...
# 23     22A  Provision of passenger and crew information in...
# 24      23  Provision of passenger and crew information by...
# 25    23AA  Provision of passenger and crew information in...
# 26     23A  Provision of passenger and crew information by...
# 27     23B  Provision of passenger and crew information in...
# 28      24             Examination of persons arriving by sea
# 29      25  Examination of persons arriving at authorised ...
# 30     25A           Examination of persons arriving by train
# 31      26  Examination of persons entering Singapore by l...
# 32      27  Power to send person to depot for further exam...
# 33      28                        Interrogation of travellers
# 34      29                                Medical examination
# 35      30  Immigration officer may give instructions to p...
# 36      44  Reports as to persons failing to continue thei...
# 37      45                                       Repatriation
# 38      57                                           Offences
# 39     57A  Prohibition of immigration offender entering o...
# 40     57B  Assisting, encouraging or inducing giving of s...
# 41     57C                            Marriage of convenience
# 39   https://sso.agc.gov.sg/Act/IA1959#pr57A-  Immigration Act
# 40   https://sso.agc.gov.sg/Act/IA1959#pr57B-  Immigration Act
# 41   https://sso.agc.gov.sg/Act/IA1959#pr57C-  Immigration Act
# 42   https://sso.agc.gov.sg/Act/IA1959#pr57D-  Immigration Act
# 43    https://sso.agc.gov.sg/Act/IA1959#pr58-  Immigration Act

# %% [markdown]
# ### 3.1.8 Income Tax Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[5])
statute_df.head(5)
# Out:
# Income Tax Act
# https://sso.agc.gov.sg/Act/ITA1947
# response: 200
# no errors, task completed!
#   section                                           title  \
# 0       1                                     Short title
# 1       2                                  Interpretation
# 2       3   Appointment of Comptroller and other officers
# 3      3A  Assignment of function or power to public body
# 4       4                           Powers of Comptroller
#
#                                        link         statute
# 0   https://sso.agc.gov.sg/Act/ITA1947#pr1-  Income Tax Act
# 1   https://sso.agc.gov.sg/Act/ITA1947#pr2-  Income Tax Act
# 2   https://sso.agc.gov.sg/Act/ITA1947#pr3-  Income Tax Act
# 3  https://sso.agc.gov.sg/Act/ITA1947#pr3A-  Income Tax Act
# 4   https://sso.agc.gov.sg/Act/ITA1947#pr4-  Income Tax Act

# %%
income_tax_act_df = statute_df.iloc[[216,218,247],:]
income_tax_act_df = income_tax_act_df.append(statute_df.iloc[265:272,:])
income_tax_act_df = income_tax_act_df.reset_index(drop=True)
income_tax_act_df
# Out:
#   section                                              title  \
# 0     65C  Failure to comply with section 64, 65, 65A or 65B
# 1     65E  Section 65B notice may be subject to confident...
# 2      86     Recovery of tax from persons leaving Singapore
# 3      94                                  General penalties
# 4     94A                 Penalty for failure to make return
# 5      95                 Penalty for incorrect return, etc.
# 6      96  Tax evasion and wilful action to obtain PIC bonus
# 7     96A  Serious fraudulent tax evasion and action to o...
# 8      97  Penalties for offences by authorised and unaut...
# 9      98    Penalty for obstructing Comptroller or officers
#
#                                         link         statute
# 0  https://sso.agc.gov.sg/Act/ITA1947#pr65C-  Income Tax Act
# 1  https://sso.agc.gov.sg/Act/ITA1947#pr65E-  Income Tax Act
# 2   https://sso.agc.gov.sg/Act/ITA1947#pr86-  Income Tax Act
# 3   https://sso.agc.gov.sg/Act/ITA1947#pr94-  Income Tax Act
# 4  https://sso.agc.gov.sg/Act/ITA1947#pr94A-  Income Tax Act
# 5   https://sso.agc.gov.sg/Act/ITA1947#pr95-  Income Tax Act
# 6   https://sso.agc.gov.sg/Act/ITA1947#pr96-  Income Tax Act
# 7  https://sso.agc.gov.sg/Act/ITA1947#pr96A-  Income Tax Act
# 8   https://sso.agc.gov.sg/Act/ITA1947#pr97-  Income Tax Act
# 9   https://sso.agc.gov.sg/Act/ITA1947#pr98-  Income Tax Act

# %% [markdown]
# ### 3.1.9 Companies Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[6])
statute_df.iloc[:50,:]
# Out:
# Companies Act
# https://sso.agc.gov.sg/Act/CoA1967
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                Division into Parts
# 2        3                                            Repeals
# 3        4                                     Interpretation
# 4        5       Definition of subsidiary and holding company
# 5       5A             Definition of ultimate holding company
# 6       5B              Definition of wholly owned subsidiary
# 7        6  When corporations deemed to be related to each...
# 8        7                                Interests in shares
# 9       7A  Solvency statement and offence for making fals...
# 10       8  Administration of Act and appointment of Regis...
# 11      8A                 Inspection of books of corporation
# 12      8B  Power of Magistrate to issue warrant to seize ...
# 13      8C  Copies of or extracts from books to be admitte...
# 14      8D  Destruction, mutilation, etc., of company docu...
# 15      8E                Saving for advocates and solicitors
# 16      8F                   Investigation of certain matters
# 17      8G  Savings for banks, insurance companies and cer...
# 18      8H                            Security of information
# 19      10                                   Company auditors
# 20      12                                          Registers
# 21     12A                      Electronic transaction system
# 22     12B                             Rectification by Court
# 23     12C          Rectification by Registrar on application
# 24     12D  Rectification or updating on Registrar’s initi...
# 25      13                Enforcement of duty to make returns
# 26      14             Relodging of lost registered documents
# 27      15  Size, durability and legibility of documents d...
# 28      17                             Formation of companies
# 29      18                                    Private company
# 30      19                     Registration and incorporation
# 31      20                       Power to refuse registration
# 32     20A                              Minimum of one member
# 33      21                      Membership of holding company
# 34      22                    Requirements as to constitution
# 35      23                     Capacity and powers of company
# 36      24  Power of company to provide for employees on c...
# 37      25                           Ultra vires transactions
# 38     25A                             No constructive notice
# 39     25B                 Power of directors to bind company
# 40     25C  Constitutional limitations: transactions with ...
# 41     25D     Persons connected with director in section 25C
# 42      26  General provisions as to alteration of constit...
# 43     26A  Power to entrench provisions of constitution o...
# 44      27                                 Names of companies
# 45      28                                     Change of name
# 46      29  Omission of "Limited" or "Berhad" in names of ...
# 47     29A  Omission of "Limited" or "Berhad" in names of ...
# 48      30  Registration of unlimited company as limited c...
# 49      31              Change from public to private company
#
#                                          link        statute
# 0     https://sso.agc.gov.sg/Act/CoA1967#pr1-  Companies Act
# 1     https://sso.agc.gov.sg/Act/CoA1967#pr2-  Companies Act
# 2     https://sso.agc.gov.sg/Act/CoA1967#pr3-  Companies Act
# 3     https://sso.agc.gov.sg/Act/CoA1967#pr4-  Companies Act
# 4     https://sso.agc.gov.sg/Act/CoA1967#pr5-  Companies Act
# 5    https://sso.agc.gov.sg/Act/CoA1967#pr5A-  Companies Act
# 6    https://sso.agc.gov.sg/Act/CoA1967#pr5B-  Companies Act
# 7     https://sso.agc.gov.sg/Act/CoA1967#pr6-  Companies Act
# 8     https://sso.agc.gov.sg/Act/CoA1967#pr7-  Companies Act
# 9    https://sso.agc.gov.sg/Act/CoA1967#pr7A-  Companies Act
# 10    https://sso.agc.gov.sg/Act/CoA1967#pr8-  Companies Act
# 11   https://sso.agc.gov.sg/Act/CoA1967#pr8A-  Companies Act
# 12   https://sso.agc.gov.sg/Act/CoA1967#pr8B-  Companies Act
# 13   https://sso.agc.gov.sg/Act/CoA1967#pr8C-  Companies Act
# 14   https://sso.agc.gov.sg/Act/CoA1967#pr8D-  Companies Act
# 15   https://sso.agc.gov.sg/Act/CoA1967#pr8E-  Companies Act
# 16   https://sso.agc.gov.sg/Act/CoA1967#pr8F-  Companies Act
companies_act_df = companies_act_df.append(statute_df.iloc[127:129,:])
companies_act_df = companies_act_df.append(statute_df.iloc[149:151,:])
companies_act_df = companies_act_df.append(statute_df.iloc[159:168,:])
companies_act_df = companies_act_df.append(statute_df.iloc[172:181,:])
companies_act_df = companies_act_df.append(statute_df.iloc[188:190,:])
companies_act_df = companies_act_df.append(statute_df.iloc[192:196,:])
companies_act_df = companies_act_df.append(statute_df.iloc[201:205,:])
companies_act_df = companies_act_df.append(statute_df.iloc[208:210,:])
companies_act_df = companies_act_df.append(statute_df.iloc[211:213,:])
companies_act_df = companies_act_df.append(statute_df.iloc[234:236,:])
companies_act_df = companies_act_df.append(statute_df.iloc[237:241,:])
companies_act_df = companies_act_df.append(statute_df.iloc[250:252,:])
companies_act_df = companies_act_df.append(statute_df.iloc[259:263,:])
companies_act_df = companies_act_df.append(statute_df.iloc[265:267,:])
companies_act_df = companies_act_df.append(statute_df.iloc[268:270,:])
companies_act_df = companies_act_df.append(statute_df.iloc[273:275,:])
companies_act_df = companies_act_df.append(statute_df.iloc[279:282,:])
companies_act_df = companies_act_df.append(statute_df.iloc[293:295,:])
companies_act_df = companies_act_df.append(statute_df.iloc[314:316,:])
companies_act_df = companies_act_df.append(statute_df.iloc[347:349,:])
companies_act_df = companies_act_df.append(statute_df.iloc[368:378,:])
companies_act_df = companies_act_df.append(statute_df.iloc[393:396,:])
companies_act_df = companies_act_df.append(statute_df.iloc[399:407,:])
companies_act_df
# Out:
#     section                                              title  \
# 9        7A  Solvency statement and offence for making fals...
# 14       8D  Destruction, mutilation, etc., of company docu...
# 18       8H                            Security of information
# 42       26  General provisions as to alteration of constit...
# 50       32  Default in complying with requirements as to p...
# ..      ...                                                ...
# 402     404      Fraudulently inducing persons to invest money
# 403     405  Penalty for carrying on business without regis...
# 404     406                                 Frauds by officers
# 405     407                         General penalty provisions
# 406     408                                  Default penalties
#
#                                           link        statute
# 9     https://sso.agc.gov.sg/Act/CoA1967#pr7A-  Companies Act
# 14    https://sso.agc.gov.sg/Act/CoA1967#pr8D-  Companies Act
# 18    https://sso.agc.gov.sg/Act/CoA1967#pr8H-  Companies Act
# 42    https://sso.agc.gov.sg/Act/CoA1967#pr26-  Companies Act
# 50    https://sso.agc.gov.sg/Act/CoA1967#pr32-  Companies Act
# ..                                         ...            ...
# 402  https://sso.agc.gov.sg/Act/CoA1967#pr404-  Companies Act
# 403  https://sso.agc.gov.sg/Act/CoA1967#pr405-  Companies Act
# 404  https://sso.agc.gov.sg/Act/CoA1967#pr406-  Companies Act
# 405  https://sso.agc.gov.sg/Act/CoA1967#pr407-  Companies Act
# 406  https://sso.agc.gov.sg/Act/CoA1967#pr408-  Companies Act
#
# [129 rows x 4 columns]

# %% [markdown]
# ### 3.1.10 Prevention of Corruption Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[7])
statute_df.iloc[:50,:]
# Out:
# Prevention of Corruption Act
# https://sso.agc.gov.sg/Act/PCA1960
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 16   https://sso.agc.gov.sg/Act/PCA1960#pr11-  Prevention of Corruption Act
# 17   https://sso.agc.gov.sg/Act/PCA1960#pr12-  Prevention of Corruption Act
# 18   https://sso.agc.gov.sg/Act/PCA1960#pr13-  Prevention of Corruption Act
# 19   https://sso.agc.gov.sg/Act/PCA1960#pr14-  Prevention of Corruption Act
# 20   https://sso.agc.gov.sg/Act/PCA1960#pr15-  Prevention of Corruption Act
# 21  https://sso.agc.gov.sg/Act/PCA1960#pr15A-  Prevention of Corruption Act
# 22   https://sso.agc.gov.sg/Act/PCA1960#pr16-  Prevention of Corruption Act
# 23   https://sso.agc.gov.sg/Act/PCA1960#pr17-  Prevention of Corruption Act
# 24   https://sso.agc.gov.sg/Act/PCA1960#pr18-  Prevention of Corruption Act
# 25   https://sso.agc.gov.sg/Act/PCA1960#pr19-  Prevention of Corruption Act
# 26   https://sso.agc.gov.sg/Act/PCA1960#pr20-  Prevention of Corruption Act
# 27   https://sso.agc.gov.sg/Act/PCA1960#pr21-  Prevention of Corruption Act
# 28   https://sso.agc.gov.sg/Act/PCA1960#pr22-  Prevention of Corruption Act
# 29   https://sso.agc.gov.sg/Act/PCA1960#pr23-  Prevention of Corruption Act
# 30   https://sso.agc.gov.sg/Act/PCA1960#pr24-  Prevention of Corruption Act
# 31   https://sso.agc.gov.sg/Act/PCA1960#pr25-  Prevention of Corruption Act
# 32   https://sso.agc.gov.sg/Act/PCA1960#pr26-  Prevention of Corruption Act
# 33   https://sso.agc.gov.sg/Act/PCA1960#pr27-  Prevention of Corruption Act
# 34   https://sso.agc.gov.sg/Act/PCA1960#pr28-  Prevention of Corruption Act
# 35   https://sso.agc.gov.sg/Act/PCA1960#pr29-  Prevention of Corruption Act
# 36   https://sso.agc.gov.sg/Act/PCA1960#pr30-  Prevention of Corruption Act
# 37   https://sso.agc.gov.sg/Act/PCA1960#pr31-  Prevention of Corruption Act
# 38   https://sso.agc.gov.sg/Act/PCA1960#pr32-  Prevention of Corruption Act
# 39   https://sso.agc.gov.sg/Act/PCA1960#pr33-  Prevention of Corruption Act
# 40   https://sso.agc.gov.sg/Act/PCA1960#pr34-  Prevention of Corruption Act
# 41   https://sso.agc.gov.sg/Act/PCA1960#pr35-  Prevention of Corruption Act
# 42   https://sso.agc.gov.sg/Act/PCA1960#pr36-  Prevention of Corruption Act
# 43   https://sso.agc.gov.sg/Act/PCA1960#pr37-  Prevention of Corruption Act

# %%
prevention_corruption_act_df = statute_df.iloc[10:13,:]
prevention_corruption_act_df = prevention_corruption_act_df.append(statute_df.iloc[14:19,:])
prevention_corruption_act_df = prevention_corruption_act_df.append(statute_df.iloc[[24,27,32],:])
prevention_corruption_act_df = prevention_corruption_act_df.append(statute_df.iloc[34:39,:])
prevention_corruption_act_df = prevention_corruption_act_df.reset_index(drop=True)
prevention_corruption_act_df
# Out:
#    section                                              title  \
# 0        5                          Punishment for corruption
# 1        6    Punishment for corrupt transactions with agents
# 2        7       Increase of maximum penalty in certain cases
# 3        9  Acceptor of gratification to be guilty notwith...
# 27   https://sso.agc.gov.sg/Act/CA1960#pr24-  Customs Act
# 28   https://sso.agc.gov.sg/Act/CA1960#pr25-  Customs Act
# 29   https://sso.agc.gov.sg/Act/CA1960#pr26-  Customs Act
# 30   https://sso.agc.gov.sg/Act/CA1960#pr27-  Customs Act
# 31   https://sso.agc.gov.sg/Act/CA1960#pr28-  Customs Act
# 32   https://sso.agc.gov.sg/Act/CA1960#pr29-  Customs Act
# 33   https://sso.agc.gov.sg/Act/CA1960#pr30-  Customs Act
# 34   https://sso.agc.gov.sg/Act/CA1960#pr31-  Customs Act
# 35   https://sso.agc.gov.sg/Act/CA1960#pr32-  Customs Act
# 36   https://sso.agc.gov.sg/Act/CA1960#pr33-  Customs Act
# 37   https://sso.agc.gov.sg/Act/CA1960#pr34-  Customs Act
# 38   https://sso.agc.gov.sg/Act/CA1960#pr36-  Customs Act
# 39   https://sso.agc.gov.sg/Act/CA1960#pr37-  Customs Act
# 40   https://sso.agc.gov.sg/Act/CA1960#pr38-  Customs Act
# 41   https://sso.agc.gov.sg/Act/CA1960#pr39-  Customs Act
# 42   https://sso.agc.gov.sg/Act/CA1960#pr40-  Customs Act
# 43   https://sso.agc.gov.sg/Act/CA1960#pr41-  Customs Act
# 44   https://sso.agc.gov.sg/Act/CA1960#pr42-  Customs Act
# 45   https://sso.agc.gov.sg/Act/CA1960#pr43-  Customs Act
# 46   https://sso.agc.gov.sg/Act/CA1960#pr44-  Customs Act
# 47   https://sso.agc.gov.sg/Act/CA1960#pr45-  Customs Act
# 48   https://sso.agc.gov.sg/Act/CA1960#pr46-  Customs Act
# 49   https://sso.agc.gov.sg/Act/CA1960#pr47-  Customs Act

# %%
customs_act_df = statute_df.iloc[[16,75,100,103],:]
customs_act_df = customs_act_df.append(statute_df.iloc[97:99,:])
customs_act_df = customs_act_df.append(statute_df.iloc[126:151,:])
customs_act_df = customs_act_df.reset_index(drop=True)
customs_act_df
# Out:
#    section                                              title  \
# 0       17   Tax on motor vehicles using heavy fuel oil, etc.
# 1       82                       Duty free shops for tourists
# 2      104               Power to search vessels and aircraft
# 3      107                                       Road barrier
# 4      102     Power of Magistrate, etc., to enter and search
# 5      103            When search may be made without warrant
# 6      128  Offences in relation to making and signing unt...
# 7     128A       Offences in relation to falsifying documents
# 8     128B  Offences in relation to failure to make declar...
# 9     128C  Offences in relation to failure to produce tra...
# 10    128D         Offences in relation to fraudulent evasion
# 11    128E  Offences in relation to goods found in person’...
# 12    128F  Offences in relation to importation of uncusto...
# 13    128G  Offences in relation to exportation of uncusto...
# 14    128H  Offences in relation to shipping, unshipping, ...
# 15    128I  Offences in relation to possession, storage, c...
# 16    128J       Offences in relation to duty-free allowances
# 17    128K  Offences in relation to illegal removal of goo...
# 18    128L                       Penalty for various offences
# 19     129  Penalty on refusing to answer questions or on ...
# 20     131  Evading duty by unauthorised modification of c...
# 21     132  Knowingly advancing or furnishing money for bu...
# 22     133  Penalty for adding deleterious substances to i...
# 23     134     Offence in connection with claims for drawback
# 24     135            Penalty for possession of a still, etc.
# 6       5B  No riding of personal mobility device, etc., w...
# 7        6       Rules as to use and construction of vehicles
# 8       6A             Alteration of fuel-measuring equipment
# 9       6B  Leaving Singapore in motor vehicle with altere...
# 10      6C  Trials and use of autonomous motor vehicles, etc.
# 11      6D  Exemptions and modified application of laws to...
# 12      6E  Interfering with autonomous motor vehicle tria...
# 13       7                                            Savings
# 14       8                              Definition of licence
# 15       9  Appointment of Registrar, Deputy Registrar and...
# 16      10                           Registration of vehicles
# 17     10A  Vehicles not to be registered without permits ...
# 18     10B  Heavy vehicle not to be registered without val...
# 19      11                          Charge of tax on vehicles
# 20    11AA                            Vehicular emissions tax
# 21     11A     Restricted licences and supplementary licences
# 22     11B        Tax upon end of exemption from permit, etc.
# 23      12                Vehicles licensed outside Singapore
# 24      13              Commencement and duration of licences
# 25      14  Exemption from tax on certain descriptions of ...
# 26      15       Using and keeping of vehicle without licence
# 27      16        Presumption as to use or keeping of vehicle
# 28      17                      Continuous liability for duty
# 29      18                           Suit for recovery of tax
# 30      19                   Issue and exhibition of licences
# 31      20               Number of persons carried on vehicle
# 32      21                       Late application for licence
# 33      22                              Surrender of licences
# 34      23                  Vehicle destroyed, exported, etc.
# 35     23A  Duty of manufacturers and dealers to notify Re...
# 36      24                Alteration of vehicle or of its use
# 37      25                                 Visitors’ vehicles
# 38      26              Registration and identification marks
# 39      27                       Cancellation of registration
# 40      28                                   General licences
# 41     28A                           Special purpose licences
# 42      29  Offences in connection with registration and l...
# 43     29A   Court may order offender to pay arrears of taxes
# 44      30                   Power to seize and sell vehicles
# 45      31  Limitation on bringing of proceedings for reco...
# 46      33  Exemptions and application to vehicles belongi...
# 47      34                    Rules for purposes of this Part
# 48     34A                        Interpretation of this Part
# 49     34B                        Levying of road-user charge
#
#                                           link           statute
# 0      https://sso.agc.gov.sg/Act/RTA1961#pr1-  Road Traffic Act
# 1      https://sso.agc.gov.sg/Act/RTA1961#pr2-  Road Traffic Act
# 2      https://sso.agc.gov.sg/Act/RTA1961#pr3-  Road Traffic Act
# 3      https://sso.agc.gov.sg/Act/RTA1961#pr4-  Road Traffic Act
# 4      https://sso.agc.gov.sg/Act/RTA1961#pr5-  Road Traffic Act
# 5     https://sso.agc.gov.sg/Act/RTA1961#pr5A-  Road Traffic Act
# 6     https://sso.agc.gov.sg/Act/RTA1961#pr5B-  Road Traffic Act
# 7      https://sso.agc.gov.sg/Act/RTA1961#pr6-  Road Traffic Act
# 8     https://sso.agc.gov.sg/Act/RTA1961#pr6A-  Road Traffic Act
# 9     https://sso.agc.gov.sg/Act/RTA1961#pr6B-  Road Traffic Act
# 10    https://sso.agc.gov.sg/Act/RTA1961#pr6C-  Road Traffic Act
# 11    https://sso.agc.gov.sg/Act/RTA1961#pr6D-  Road Traffic Act
# 12    https://sso.agc.gov.sg/Act/RTA1961#pr6E-  Road Traffic Act
# 13     https://sso.agc.gov.sg/Act/RTA1961#pr7-  Road Traffic Act
# 14     https://sso.agc.gov.sg/Act/RTA1961#pr8-  Road Traffic Act
# 15     https://sso.agc.gov.sg/Act/RTA1961#pr9-  Road Traffic Act
:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[108:110,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[111:116,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[117:120,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[125:131,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[132:134,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[143:146,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[156:158,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[159:167,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[168:172,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[177:179,:])
road_traffic_act_df = road_traffic_act_df.append(statute_df.iloc[193:195,:])
road_traffic_act_df = road_traffic_act_df.reset_index(drop=True)
road_traffic_act_df
# Out:
#    section                                              title  \
# 0        5  Prohibition of vehicles not complying with rul...
# 1       5A  No riding of personal mobility devices, etc., ...
# 2       5B  No riding of personal mobility device, etc., w...
# 3       6A             Alteration of fuel-measuring equipment
# 4       6B  Leaving Singapore in motor vehicle with altere...
# ..     ...                                                ...
# 86    127B  Powers of search on omnibuses and within bus i...
# 87    131B                 Offences by bodies corporate, etc.
# 88     132                   Ticketing of prescribed offences
# 89     143  Regulation of traffic in connection with event...
# 90     144           Property left in public service vehicles
#
#                                           link           statute
# 0      https://sso.agc.gov.sg/Act/RTA1961#pr5-  Road Traffic Act
# 1     https://sso.agc.gov.sg/Act/RTA1961#pr5A-  Road Traffic Act
# 2     https://sso.agc.gov.sg/Act/RTA1961#pr5B-  Road Traffic Act
# 3     https://sso.agc.gov.sg/Act/RTA1961#pr6A-  Road Traffic Act
# 4     https://sso.agc.gov.sg/Act/RTA1961#pr6B-  Road Traffic Act
# ..                                         ...               ...
# 86  https://sso.agc.gov.sg/Act/RTA1961#pr127B-  Road Traffic Act
# 87  https://sso.agc.gov.sg/Act/RTA1961#pr131B-  Road Traffic Act
# 88   https://sso.agc.gov.sg/Act/RTA1961#pr132-  Road Traffic Act
# 89   https://sso.agc.gov.sg/Act/RTA1961#pr143-  Road Traffic Act
# 90   https://sso.agc.gov.sg/Act/RTA1961#pr144-  Road Traffic Act
#
# [91 rows x 4 columns]

# %% [markdown]
# ### 3.1.13  Environmental Public Health Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[10])
statute_df.iloc[:50,:]
# Out:
# Environmental Public Health Act
# https://sso.agc.gov.sg/Act/EPHA1987
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2        3  Appointment of Director-General and authorised...
# 3        4            Delegation of power by Director-General
# 4        5  Director-General to cause public streets, etc....
# 5        6  Duty of owner and occupier to keep clean priva...
# 6        7                                Dustbins in streets
# 7        8  Director-General may apply systems for collect...
# 8        9   Removal of industrial waste, stable refuse, etc.
# 9       10  Director-General may require owner and occupie...
# 10      11  Maintenance of refuse lifts and chutes and chu...
# 11      12                 Occupier of house to remove refuse
# 12      13  Prohibition on use of nightsoil or human excre...
# 13      14  Prohibition on use of nightsoil or human excre...
# 14      15  Prohibition of cultivation or use of manure or...
# 15      16  All refuse, etc., collected to be property of ...
# 16      17  Prohibition against throwing refuse, etc., in ...
# 17      18  Building works constituting danger to life, he...
# 18      19  Prohibition against dropping, scattering, etc....
# 19      20          Prohibition against dumping and disposing
# 20      21                             Notice to attend Court
# 21     21A                              Corrective work order
# 22     21B  Obligations of person subject to corrective wo...
# 23     21C                    Breach of corrective work order
# 24     21D  Variation and revocation of corrective work order
# 25     21E               Interpretation of sections 21 to 21D
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[34:36,:])
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[45:48,:])
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[51:53,:])
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[59:70,:])
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[110:113,:])
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[126:128,:])
environmental_public_health_act_df = environmental_public_health_act_df.append(statute_df.iloc[145:147,:])
environmental_public_health_act_df = environmental_public_health_act_df.reset_index(drop=True)
environmental_public_health_act_df
# Out:
#    section                                              title  \
# 0       12                 Occupier of house to remove refuse
# 1       13  Prohibition on use of nightsoil or human excre...
# 2       17  Prohibition against throwing refuse, etc., in ...
# 3       18  Building works constituting danger to life, he...
# 4       19  Prohibition against dropping, scattering, etc....
# 5       20          Prohibition against dumping and disposing
# 6       21                             Notice to attend Court
# 7      21A                              Corrective work order
# 8      21C                    Breach of corrective work order
# 9       29  Dangerous substance or toxic industrial waste ...
# 10     31G                         Declaration of DPWCS areas
# 11      45                                     Nuisance order
# 12      58  Drains, etc., to be kept in order at cost of o...
# 13      73                                   Unlawful burials
# 14      76                                         Exhumation
# 15      79           Provision of water suitable for drinking
# 16     80A                          Regulations for this Part
# 17     80M                                  Monitoring powers
# 18     88A                    False or misleading information
# 19      92   Recovery of costs and expenses payable by owners
# 20      99                                           Licences
# 21     111                                        Regulations
# 22      23  No disposal facility to be constructed, etc., ...
# 23      24  Prohibition against disposal of industrial was...
# 24     30A  Furnishing of information and keeping, etc., o...
# 25      31  Licensing of persons carrying on business of c...
# 26     31J  No collection of waste or waste through DPWCS,...
# 27     31K                            Works by DPWCS licensee
# 28     31L  Director-General may require owner or occupier...
# 29     31P                  Duty to enquire before excavation
# 30     31Q                                    Damage to DPWCS
# 31      32                 Food establishments to be licensed
# 32      33   Licensing of hawkers operating from stalls, etc.
# 33      34                     Licensing of itinerant hawkers
# 34      35  Director-General, Food Administration may issu...
# 35      36                       Licences for private markets
# 36      37  Persons with infectious diseases not to carry ...
# 37      38                            Unauthorised structures
# 38      39                  Cleanliness of markets and stalls
# 39      40       Articles of food unfit for human consumption
# 40      41           Cleanliness of vehicles, equipment, etc.
# 41     41A             Penalties for offences under this Part
# 42     80D  Carrying on cleaning business without cleaning...
# 43     80E               Offence to engage unlicensed persons
# 44     80F          Application for cleaning business licence
# 45      85                  Default in compliance with notice
# 46      86  Authorised officers may demand names and addre...
# 47     103                                  General penalties
# 48    103A                 Offences by bodies corporate, etc.
#
#                                            link  \
# 0     https://sso.agc.gov.sg/Act/EPHA1987#pr12-
# 1     https://sso.agc.gov.sg/Act/EPHA1987#pr13-
# 2     https://sso.agc.gov.sg/Act/EPHA1987#pr17-
# 3     https://sso.agc.gov.sg/Act/EPHA1987#pr18-
# 4     https://sso.agc.gov.sg/Act/EPHA1987#pr19-
# 5     https://sso.agc.gov.sg/Act/EPHA1987#pr20-
# 6   Environmental Public Health Act
# 7   Environmental Public Health Act
# 8   Environmental Public Health Act
# 9   Environmental Public Health Act
# 10  Environmental Public Health Act
# 11  Environmental Public Health Act
# 12  Environmental Public Health Act
# 13  Environmental Public Health Act
# 14  Environmental Public Health Act
# 15  Environmental Public Health Act
# 16  Environmental Public Health Act
# 17  Environmental Public Health Act
# 18  Environmental Public Health Act
# 19  Environmental Public Health Act
# 20  Environmental Public Health Act
# 21  Environmental Public Health Act
# 22  Environmental Public Health Act
# 23  Environmental Public Health Act
# 24  Environmental Public Health Act
# 25  Environmental Public Health Act
# 26  Environmental Public Health Act
# 27  Environmental Public Health Act
# 28  Environmental Public Health Act
# 29  Environmental Public Health Act
# 30  Environmental Public Health Act
# 31  Environmental Public Health Act
# 32  Environmental Public Health Act
# 33  Environmental Public Health Act
# 34  Environmental Public Health Act
# 35  Environmental Public Health Act
# 36  Environmental Public Health Act
# 37  Environmental Public Health Act
# 38  Environmental Public Health Act
# 39  Environmental Public Health Act
# 40  Environmental Public Health Act
# 41  Environmental Public Health Act
# 42  Environmental Public Health Act
# 43  Environmental Public Health Act
# 44  Environmental Public Health Act
# 45  Environmental Public Health Act
# 46  Environmental Public Health Act
# 47  Environmental Public Health Act
# 48  Environmental Public Health Act

# %% [markdown]
# ### 3.1.14 Computer Misuse Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[11])
statute_df.iloc[:50,:]
# Out:
# Computer Misuse Act
# https://sso.agc.gov.sg/Act/CMA1993
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2        3           Unauthorised access to computer material
# 3        4  Access with intent to commit or facilitate com...
# 4        5     Unauthorised modification of computer material
# 5        6  Unauthorised use or interception of computer s...
# 6        7        Unauthorised obstruction of use of computer
# 7        8             Unauthorised disclosure of access code
# 8       8A  Supplying, etc., personal information obtained...
# 9       8B  Obtaining, etc., items for use in certain offe...
# 10       9  Enhanced punishment for offences involving pro...
# 11      10      Abetments and attempts punishable as offences
# 12      11       Territorial scope of offences under this Act
# 13     11A                            Amalgamation of charges
# 14      12                             Jurisdiction of Courts
# 15     12A                            Composition of offences
# 16      13                  Order for payment of compensation
# 17      14  Saving for investigations by police and law en...
# 18      16                   Arrest by police without warrant
#
#                                          link              statute
# 0     https://sso.agc.gov.sg/Act/CMA1993#pr1-  Computer Misuse Act
# 1     https://sso.agc.gov.sg/Act/CMA1993#pr2-  Computer Misuse Act
# 2     https://sso.agc.gov.sg/Act/CMA1993#pr3-  Computer Misuse Act
# 3     https://sso.agc.gov.sg/Act/CMA1993#pr4-  Computer Misuse Act
# 4     https://sso.agc.gov.sg/Act/CMA1993#pr5-  Computer Misuse Act
# 5     https://sso.agc.gov.sg/Act/CMA1993#pr6-  Computer Misuse Act
# 6     https://sso.agc.gov.sg/Act/CMA1993#pr7-  Computer Misuse Act
# 7     https://sso.agc.gov.sg/Act/CMA1993#pr8-  Computer Misuse Act
# 8    https://sso.agc.gov.sg/Act/CMA1993#pr8A-  Computer Misuse Act
# 9    https://sso.agc.gov.sg/Act/CMA1993#pr8B-  Computer Misuse Act
# 10    https://sso.agc.gov.sg/Act/CMA1993#pr9-  Computer Misuse Act
# 11   https://sso.agc.gov.sg/Act/CMA1993#pr10-  Computer Misuse Act
# 12   https://sso.agc.gov.sg/Act/CMA1993#pr11-  Computer Misuse Act
# 13  https://sso.agc.gov.sg/Act/CMA1993#pr11A-  Computer Misuse Act
# 14   https://sso.agc.gov.sg/Act/CMA1993#pr12-  Computer Misuse Act
# 15  https://sso.agc.gov.sg/Act/CMA1993#pr12A-  Computer Misuse Act
# 16   https://sso.agc.gov.sg/Act/CMA1993#pr13-  Computer Misuse Act
# 17   https://sso.agc.gov.sg/Act/CMA1993#pr14-  Computer Misuse Act
# 18   https://sso.agc.gov.sg/Act/CMA1993#pr16-  Computer Misuse Act

# %%
computer_misuse_act_df = statute_df.iloc[2:12,:]
computer_misuse_act_df = computer_misuse_act_df.reset_index(drop=True)
computer_misuse_act_df
# Out:
#   section                                              title  \
# 0       3           Unauthorised access to computer material
# 1       4  Access with intent to commit or facilitate com...
# 2       5     Unauthorised modification of computer material
# 3       6  Unauthorised use or interception of computer s...
# 4       7        Unauthorised obstruction of use of computer
# 5       8             Unauthorised disclosure of access code
# 6      8A  Supplying, etc., personal information obtained...
# 7      8B  Obtaining, etc., items for use in certain offe...
# 8       9  Enhanced punishment for offences involving pro...
# 9      10      Abetments and attempts punishable as offences
#
#                                        link              statute
# 0   https://sso.agc.gov.sg/Act/CMA1993#pr3-  Computer Misuse Act
# 1   https://sso.agc.gov.sg/Act/CMA1993#pr4-  Computer Misuse Act
# 2   https://sso.agc.gov.sg/Act/CMA1993#pr5-  Computer Misuse Act
# 3   https://sso.agc.gov.sg/Act/CMA1993#pr6-  Computer Misuse Act
# 4   https://sso.agc.gov.sg/Act/CMA1993#pr7-  Computer Misuse Act
# 5   https://sso.agc.gov.sg/Act/CMA1993#pr8-  Computer Misuse Act
# 6  https://sso.agc.gov.sg/Act/CMA1993#pr8A-  Computer Misuse Act
# 7  https://sso.agc.gov.sg/Act/CMA1993#pr8B-  Computer Misuse Act
# 8   https://sso.agc.gov.sg/Act/CMA1993#pr9-  Computer Misuse Act
# 9  https://sso.agc.gov.sg/Act/CMA1993#pr10-  Computer Misuse Act

# %% [markdown]
# ### 3.1.15 Employment Agencies Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[13])
statute_df.iloc[:50,:]
# Out:
# Employment Agencies Act
# https://sso.agc.gov.sg/Act/EAA1958
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2        3                            Appointment of officers
# 3        4                                        Application
# 4        5                            Other laws not affected
# 5        6                            Requirement for licence
# 6        7                            Application for licence
# 7        8                                           Security
# 8       10                      Period of validity of licence
# 9       11                Suspension or revocation of licence
# 10      12      Effect of suspension or revocation of licence
# 11     12A        Registration of employment agency personnel
# 12     12B                                 Registration cards
# 13      13                                            Appeals
# 14      14                         Fees for services rendered
# 15      15                    Offer of fees, etc., prohibited
# 4   https://sso.agc.gov.sg/Act/EAA1958#pr12A-  Employment Agencies Act
# 5   https://sso.agc.gov.sg/Act/EAA1958#pr12B-  Employment Agencies Act
# 6    https://sso.agc.gov.sg/Act/EAA1958#pr22-  Employment Agencies Act
# 7   https://sso.agc.gov.sg/Act/EAA1958#pr22A-  Employment Agencies Act
# 8   https://sso.agc.gov.sg/Act/EAA1958#pr22B-  Employment Agencies Act
# 9   https://sso.agc.gov.sg/Act/EAA1958#pr22C-  Employment Agencies Act
# 10   https://sso.agc.gov.sg/Act/EAA1958#pr23-  Employment Agencies Act
# 11  https://sso.agc.gov.sg/Act/EAA1958#pr28A-  Employment Agencies Act
# 12  https://sso.agc.gov.sg/Act/EAA1958#pr28B-  Employment Agencies Act

# %% [markdown]
# ### 3.1.16 Employment of Foreign Manpower Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[14])
statute_df.iloc[:51,:]
# Out:
# Employment of Foreign Manpower Act
# https://sso.agc.gov.sg/Act/EFMA1990
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2       2A                   Meaning of "personal identifier"
# 3        3  Appointment of Controller of Work Passes and e...
# 4       3A  Controller and employment inspectors to be pub...
# 5        4                                          Exemption
# 6        5  Prohibition of employment of foreign employee ...
# 7        6                          Presumption of employment
# 8       6A  Prohibition of foreigner without work pass ent...
# 9        7                          Application for work pass
# 10       8  Register of foreign employees to be kept by em...
# 11       9     Termination of employment of foreign employees
# 12      10  Self-employed foreigners to apply for work passes
# 13      11  Levy in respect of foreign employee or self-em...
# 14      12                    Extent of validity of work pass
# 15      13                         Custody of work pass, etc.
# 16      14                           Loss, etc., of work pass
# 17      15                              Burden of proof, etc.
# 18      16  Powers of authorised officers and employment i...
# 19      17                                  Change of address
# 20      18                                 Service of notices
# 21      19                 Protection from personal liability
# 22      20                 Offences by bodies corporate, etc.
# 23      21                    Power to arrest without warrant
# 24     21A                                    Arrest how made
# 25     21B                           No unnecessary restraint
# 26     21C                         Search of persons arrested
# 27     21D                   Employment inspector to be armed
# 28     21E                   Power to seize offensive weapons
# 29     21F               Power on escape to pursue and arrest
# 30     21G                  Disposal of documents or articles
# 31      22                                   General offences
# 32     22A  Restrictions on receipt, etc., of moneys in co...
# 33     22B              Proscribed manpower-related practices
# 34      23                               Abetment of offences
# 35     23A            Orders for payment of proceeds of crime
# 36      24                  Complaint by employment inspector
# 37      25                   General prescribed infringements
# 38     25A                  Compliance with prescribed duties
# 39     25B                                         Directions
# 40     25C           Proceedings for prescribed infringements
# 41     25D                    Recovery of financial penalties
# 42     25E  Prescribed infringements by bodies corporate, ...
# 43     25F               Abetment of prescribed infringements
# 44     25G                            Appeals to Appeal Board
# 45     25H          Composition and procedure of Appeal Board
# 46      26                             Jurisdiction of Courts
# 47      27                            Composition of offences
# 48      28                                              Forms
# 49      29                                        Regulations
# 50      30                            Transitional provisions
#
#                                           link  \
# 0     https://sso.agc.gov.sg/Act/EFMA1990#pr1-
# 1     https://sso.agc.gov.sg/Act/EFMA1990#pr2-
# 2   https://sso.agc.gov.sg/Act/EFMA1990#pr20-
# 3  https://sso.agc.gov.sg/Act/EFMA1990#pr25B-
# 4   https://sso.agc.gov.sg/Act/EFMA1990#pr10-
# 5   https://sso.agc.gov.sg/Act/EFMA1990#pr11-
# 6   https://sso.agc.gov.sg/Act/EFMA1990#pr22-
# 7  https://sso.agc.gov.sg/Act/EFMA1990#pr22A-
# 8  https://sso.agc.gov.sg/Act/EFMA1990#pr22B-
# 9   https://sso.agc.gov.sg/Act/EFMA1990#pr23-
#
#                               statute
# 0  Employment of Foreign Manpower Act
# 1  Employment of Foreign Manpower Act
# 2  Employment of Foreign Manpower Act
# 3  Employment of Foreign Manpower Act
# 4  Employment of Foreign Manpower Act
# 5  Employment of Foreign Manpower Act
# 6  Employment of Foreign Manpower Act
# 7  Employment of Foreign Manpower Act
# 8  Employment of Foreign Manpower Act
# 9  Employment of Foreign Manpower Act

# %% [markdown]
# ### 3.1.17 Workplace Safety and Health Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[15])
statute_df.iloc[:50,:]
# Out:
# Workplace Safety and Health Act
# https://sso.agc.gov.sg/Act/WSHA2006
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                 Application of Act
# 2        3                   Application of Act to Government
# 3        4                             General interpretation
# 4        5              Meanings of "workplace" and "factory"
# 5        6              Meanings of "employee" and "employer"
# 6        7  Appointment of Commissioner for Workplace Safe...
# 7        8  Commissioner, Deputy Commissioners, inspectors...
# 8        9  Identification of inspectors and authorised of...
# 9       10           Duties according to different capacities
# 10      11                      Duty of occupier of workplace
# 11      12                                Duties of employers
# 12      13                    Duties of self-employed persons
# 13      14                               Duties of principals
# 14     14A  Additional duties of principals in relation to...
# 15      15                          Duties of persons at work
# 16      16  Duties of manufacturers and suppliers of machi...
# 17      17  Duties of persons who erect, install or modify...
# 18      18    Other related duties of occupiers and employers
# 19      19                Duties of occupiers of common areas
# 20      20          Offence of breaching duty under this Part
# 21      21   Power to issue remedial order or stop-work order
# 22      22             Appeal from order made by Commissioner
# 23      23                       Power to suspend certificate
# 24      24  Investigation into accidents, dangerous occurr...
# 25      25  Alteration or addition to machinery, equipment...
# 26      26             Minister may direct inquiry to be held
# 27      27  Notification and reporting of accidents, dange...
# 28     27A                  Learning report of accident, etc.
# 29     27B  Learning report, etc., not admissible in evidence
# 30      28  Workplace safety and health officers and co-or...
# 31      29             Workplace safety and health committees
# 32      30               Workplace safety and health auditors
# 33      31                 Safety and health training courses
# 34      32    Requirement for approval of Commissioner to act
# 35      33              Application for and grant of approval
# 36      34                               Duration of approval
# 37      35                           Cancellation of approval
# 38      36                           Surrender of certificate
# 39      37                          False assumption of title
# 40      38                            Offence under this Part
# 41      39  Establishment of Workplace Safety and Health C...
# 42      40                  Powers and proceedings of Council
# 43     40A                               Functions of Council
# 44     40B                                  Codes of practice
# 45     40C  Use of approved codes of practice in criminal ...
# 46      41                               Powers of inspectors
# 47      42                              Power to take samples
# 48      43             Power to examine and secure attendance
# 8  https://sso.agc.gov.sg/Act/WICA2019#pr73-  Work Injury Compensation Act

# %% [markdown]
# ### 3.1.19 Corruption, Drug Trafficking and Other Serious Crimes (Confiscation of Benefits) Act

# %%
statute_df = get_statute_sections(statutes['statute'].values[17])
statute_df.iloc[:50,:]
# Out:
# Corruption, Drug Trafficking and Other Serious Crimes (Confiscation of Benefits) Act
# https://sso.agc.gov.sg/Act/CDTOSCCBA1992
# response: 200
# no errors, task completed!
#    section                                              title  \
# 0        1                                        Short title
# 1        2                                     Interpretation
# 2       2A       Meaning of "item subject to legal privilege"
# 3        3                                        Application
# 4       3A            Suspicious Transaction Reporting Office
# 5        4                                Confiscation orders
# 6        5  Confiscation orders for benefits derived from ...
# 7       5A  Confiscation order unaffected by confiscation ...
# 8        6                Live video or live television links
# 9        7                 Assessing benefits of drug dealing
# 10       8   Assessing benefits derived from criminal conduct
# 11       9  Statements relating to drug dealing or crimina...
# 12      10    Amount to be recovered under confiscation order
# 13      11   Interest on sums unpaid under confiscation order
# 14      12                 Definition of principal terms used
# 15      13                Protection of rights of third party
# 16      14       Application of procedure for enforcing fines
# 17      15  Cases in which restraint orders and charging o...
# 18      16                                   Restraint orders
# 19      17  Charging orders in respect of land, capital ma...
# 20      18          Charging orders: supplementary provisions
# 21      19                            Realisation of property
# 22      20  Application of proceeds of realisation and oth...
# 23      21  Exercise of powers by General Division of High...
# 24      22                   Variation of confiscation orders
# 25      23                      Bankruptcy of defendant, etc.
# 26      24  Winding up of company holding realisable property
# 27      25                Receivers: supplementary provisions
# 28      26                                  Absconded persons
# 29      27      Confiscation order where person has absconded
# 30      28                     Effect of death on proceedings
# 31      29                 Service of documents on absconders
# 32     29A                                Application of Part
# 33     29B             Substitute property confiscation order
# 34     29C       Modified application of Parts II, III and IV
# 35      30                                  Production orders
# 36      31  Production orders against financial institutio...
# 37      32                      Variation of production order
# 38      33            Failure to comply with production order
# 39      34                               Authority for search
# 40      35  Supplementary provisions to sections 30, 32 an...
# 41      36                    Interpretation of this Division
# 42      37     Retention of records by financial institutions
# 43      38                     Register of original documents
# 44      39            Duty to disclose knowledge or suspicion
# 45      40  Protection where information given under secti...
# 46     40A  Information and identity of informers not to b...
# 47      41  Communication of information to foreign authority
# 48      42    Disclosure of information held by public bodies
# 49      43  Assisting another to retain benefits of drug d...
#
#                                                link  \
# 0     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr1-
# 1     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr2-
# 2    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr2A-
# 3     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr3-
# 4    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr3A-
# 5     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr4-
# 6     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr5-
# 7    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr5A-
# 8     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr6-
# 9     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr7-
# 10    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr8-
# 11    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr9-
# 12   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr10-
# 13   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr11-
# 14   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr12-
# 15   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr13-
# 16   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr14-
# 17   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr15-
# 18   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr16-
# 19   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr17-
# 20   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr18-
# 21   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr19-
# 22   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr20-
# 23   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr21-
# 24   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr22-
# 25   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr23-
# 26   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr24-
# 27   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr25-
# 28   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr26-
# 29   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr27-
# 30   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr28-
# 31   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr29-
# 32  https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr29A-
# 33  https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr29B-
# 34  https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr29C-
# 35   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#p
corruption_drug_serious_crimes_act_df = corruption_drug_serious_crimes_act_df.append(statute_df.iloc[[56,59,76,79,84],:])
corruption_drug_serious_crimes_act_df = corruption_drug_serious_crimes_act_df.append(statute_df.iloc[61:63,:])
corruption_drug_serious_crimes_act_df = corruption_drug_serious_crimes_act_df.append(statute_df.iloc[66:70,:])
corruption_drug_serious_crimes_act_df = corruption_drug_serious_crimes_act_df.reset_index(drop=True)
corruption_drug_serious_crimes_act_df
# Out:
#    section                                              title  \
# 0       33            Failure to comply with production order
# 1       34                               Authority for search
# 2       37     Retention of records by financial institutions
# 3       38                     Register of original documents
# 4       39            Duty to disclose knowledge or suspicion
# 5       43  Assisting another to retain benefits of drug d...
# 6       44  Assisting another to retain benefits from crim...
# 7       45  Restriction on revealing disclosure under sect...
# 8       46  Acquiring, possessing, using, concealing or tr...
# 9       47  Acquiring, possessing, using, concealing or tr...
# 10    47AA  Possessing or using property reasonably suspec...
# 11      48                                        Tipping-off
# 12     48C       Reports about cross border movements of cash
# 13      56                            Preservation of secrecy
# 14      59                 Offences by bodies corporate, etc.
# 15      64                                        Regulations
# 16     48E  Reports about receipts of cash from outside Si...
# 17     48F  Questioning and search powers in relation to cash
# 18     48I              Customer due diligence measures, etc.
# 19     48J                           Cash transaction reports
# 20     48K                                 Keeping of records
# 21      49               Offence of prejudicing investigation
#
#                                                 link  \
# 0     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr33-
# 1     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr34-
# 2     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr37-
# 3     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr38-
# 4     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr39-
# 5     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr43-
# 6     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr44-
# 7     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr45-
# 8     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr46-
# 9     https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr47-
# 10  https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr47AA-
# 11    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48-
# 12   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48C-
# 13    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr56-
# 14    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr59-
# 15    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr64-
# 16   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48E-
# 17   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48F-
# 18   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48I-
# 19   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48J-
# 20   https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr48K-
# 21    https://sso.agc.gov.sg/Act/CDTOSCCBA1992#pr49-
#
#                                               statute
# 0   Corruption, Drug Trafficking and Other Serious...
# 1   Corruption, Drug Trafficking and Other Serious...
# 2   Corruption, Drug Trafficking and Other Serious...
# 3   Corruption, Drug Trafficking and Other Serious...
# 4   Corruption, Drug Trafficking and Other Serious...
# 5   Corruption, Drug Trafficking and Other Serious...
# 6   Corruption, Drug Trafficking and Other Serious...
# 7   Corruption, Drug Trafficking and Other Serious...
# 8   Corruption, Drug Trafficking and Other Serious...
# 9   Corruption, Drug Trafficking and Other Serious...
# 10  Corruption, Drug Trafficking and Other Serious...
# 11  Corruption, Drug Trafficking and Other Serious...
# 12  Corruption, Drug Trafficking and Other Serious...
# 13  Corruption, Drug Trafficking and Other Serious...
# 14  Corruption, Drug Trafficking and Other Serious...
# 15  Corruption, Drug Trafficking and Other Serious...
# 16  Corruption, Drug Trafficking and Other Serious...
# 17  Corruption, Drug Trafficking and Other Serious...
# 18  Corruption, Drug Trafficking and Other Serious...
# 19  Corruption, Drug Trafficking and Other Serious...
# 20  Corruption, Drug Trafficking and Other Serious...
# 21  Corruption, Drug Trafficking and Other Serious...

# %% [markdown]
# ## 3.2 Combining the database of crimes
#
# Now that I have dataframes for each of the statutes, I will combine them into a single database which will be used for the NLP to recognise.

# %%
dataframes = [penal_code_df, misuse_drugs_act_df, sedition_act_df, vandalism_act_df, children_young_persons_act_df, immigration_act_df, income_tax_act_df, companies_act_df, prevention_corruption_act_df, customs_act_df, road_traffic_act_df, environmental_public_health_act_df, computer_misuse_act_df, employment_agencies_act_df, employment_foreign_manpower_act_df, workplace_safety_health_act_df, work_injury_compensation_act_df, corruption_drug_serious_crimes_act_df]

# %%
statutes_crimes = pd.concat(dataframes).reset_index(drop=True)

# %% [markdown]
# In order to allow the Natural Language Processing to identify the crime titles, I will combine the section and statute to a new column `section_statute` as an identifier as there may be sections from different statutes which share the same number.

# %%
statutes_crimes['section_statute'] = statutes_crimes['section'] + " " + statutes_crimes['statute']

# %%
statutes_crimes.to_csv('../data/statutes_crimes.csv', index=False)

# %% [markdown]
# ## Observations
#
# Webscraping to archive the .html files of the judgments was less complicated than I had first imagined as it would be. The process of identifying the structure of the html code to iterate through each page to save the cases and urls, as well as to iterate through each url to save the html file was a fun process which made full use of my logical thinking skills.
#
# However, having performed the above filtering of sections from the statutes manually, it becomes all the more apparent how useful Machine Learning will be in the legal industry.
#
# It took me roughly 6 hours over 3 days to manually filter the sections which contained offences out of the 18 statutes and add them into dataframes.
#
# Worthy of a project itself, it would be interesting to explore the use of NLP to identify sections prescribing criminal offences and sections containing their corresponding punishments from the various statutes in order to create a comprehensive database of criminal offences in the statutes of Singapore.
#
# The webscraping portion of the code has achieved a 100% pulling and archival rate, as no judgments were missed out.

# %% [markdown]
# ## References

# %% [markdown]
# [1] ALL-SIS Task Force on Identifying Skills and Knowledge for Legal Practice, *'A Study of Attorneys' Legal Research Practices and Opinions of New Associates' Research Skills,'* June 2013. [Online]. Available: [https://www.aallnet.org/allsis/wp-content/uploads/sites/4/2018/01/final_report_07102013.pdf](https://www.aallnet.org/allsis/wp-content/uploads/sites/4/2018/01/final_report_07102013.pdf) [Accessed: May. 6, 2021].

# %% [markdown]
# [2] LawNet, a service provided by the Singapore Academy of Law, *'Latest Singapore Judgments - Supreme Court Judgments of the last 3 months'*, 2021. [Online]. Available: [https://www.lawnet.sg/lawnet/web/lawnet/free-resources?p_p_id=freeresources_WAR_lawnet3baseportlet&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&p_p_col_id=column-1&p_p_col_pos=2&p_p_col_count=3&_freeresources_WAR_lawnet3baseportlet_action=supreme&_freeresources_WAR_lawnet3baseportlet_page=1](https://www.lawnet.sg/lawnet/web/lawnet/free-resources?p_p_id=freeresources_WAR_lawnet3baseportlet&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&p_p_col_id=column-1&p_p_col_pos=2&p_p_col_count=3&_freeresources_WAR_lawnet3baseportlet_action=supreme&_freeresources_WAR_lawnet3baseportlet_page=1) [Accessed: May 28, 2021].

# %% [markdown]
# [3] Glora James-Civetta & Co, Advocates & Solicitors, *'Crimes Punishment'*, 2020. [Online]. Available: [https://www.singaporecriminallawyer.com/crimes-punishment/](https://www.singaporecriminallawyer.com/crimes-punishment/) [Accessed: May 8, 2021].
